# %% [markdown]
# ### Building the model without parameters

# %%
X_train.head()
# Out:
#             branded_search_spend  nonbranded_search_spend  facebook_spend  \
# Week
# 2017-07-30                1575.6                      NaN         819.312
# 2017-08-06                1544.4                     9.36         749.034
# 2017-08-13                1528.8                    -9.36         741.468
# 2017-08-20                1560.0                    -9.36         811.200
# 2017-08-27                1606.8                    14.04         827.502
#
#             print_spend  ooh_spend  tv_spend  radio_spend
# Week
# 2017-07-30            0        NaN       NaN            0
# 2017-08-06            0        0.0       0.0            0
# 2017-08-13            0        0.0       0.0            0
# 2017-08-20            0        0.0       0.0            0
# 2017-08-27            0        0.0       0.0            0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[428], line 9
#       6 ridge = Ridge(alpha = alpha, positive=True)
#       8 # Use R² scoring
# ----> 9 r2_scores = cross_val_score(ridge, X_train_tran, y_train, cv=KFS, scoring='r2')
#      10 alpha = round(alpha, 2)
#      11 print(alpha)
#
# NameError: name 'X_train_tran' is not defined

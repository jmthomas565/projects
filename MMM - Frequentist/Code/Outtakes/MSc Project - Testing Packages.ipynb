# %%
import os 
cwd = os.getcwd()
cwd

os.chdir("/Users/jmthomas565/Desktop/Education/Applied Stats MSc/MSc Project/Datasets")

cwd
# Out:
# '/Users/jmthomas565/Desktop/Education/Applied Stats MSc/MSc Project/Git Files/msc-project-source-code-files-24-25-jmthomas565'

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import matplotlib.dates as mdates

# %%
bike_sales_data = pd.read_csv("bike_sales_data.csv")

base_rate_usa = pd.read_csv("base_rate_usa.csv")

gdp_usa = pd.read_csv("gdp_usa.csv")

unemployment_rate_usa = pd.read_csv("unemployment_rate_usa.csv")

# %% [markdown]
# ### Cleansing Bike Sales Data

# %%
bike_sales_data = bike_sales_data.set_index("Week")

bike_sales_data.index = pd.to_datetime(bike_sales_data.index)

bike_sales_data.index.dtype
# Out:
# /var/folders/5k/0mrs71sj38b3m6trnqsfqlx00000gp/T/ipykernel_91519/1501828926.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bike_sales_data.index = pd.to_datetime(bike_sales_data.index)
# dtype('<M8[ns]')

# %%
bike_sales_data["Month"] = bike_sales_data.index.strftime('%Y-%m')

#monthly_bike_sales = bike_sales_data[["Month", "sales"]]

#monthly_bike_sales = monthly_bike_sales.set_index("Month")

monthly_bike_sales = bike_sales_data.groupby(['Month'])['sales'].sum()

monthly_bike_sales = monthly_bike_sales.to_frame()

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
max(bike_sales_data['sales'])
# Out:
# 113762.88

# %% [markdown]
# ##Setting up Graphs

# %%
fig, ax = plt.subplots()
import matplotlib.ticker as ticker

ax.plot(bike_sales_data.index, bike_sales_data['sales']/1000, linestyle = 'solid', marker = 'o', markersize=2, linewidth = '1.4', c='b')

ax.xaxis.set_tick_params(rotation=70, labelsize=10)

#ax.set_xticks(np.arange(min(bike_sales_data.index),max(bike_sales_data.index),12))

ax.set_yticks(np.arange(0, 140, 10))

ax.yaxis.set_tick_params(labelsize=10)

ax.spines['top'].set_visible(False)

ax.spines['right'].set_visible(False)

ax.xaxis.labelpad=20

ax.yaxis.labelpad=20

ax.grid (color='grey', linestyle='-', linewidth=0.25, alpha=1)

ax.set_xlabel('Year', fontsize = 12)
ax.set_ylabel('Marketing Channel Spend (in £1000)', fontsize = 12)


#ax.set_xlim('2021-01', '2022-01')
# Out:
# Text(0, 0.5, 'Marketing Channel Spend (in £1000)')

# %%
class var_graph:
    def __init__(self, x_var, y_var, x_var_name, y_var_name, y_upper_bound):
        self.x_var = x_var
        self.y_var = y_var
        self.x_var_name = x_var_name
        self.y_var_name = y_var_name
        self.y_upper_bound = y_upper_bound
    def plot_graph(self):

        
        fig, ax = plt.subplots()
        
        ax.plot(self.x_var, self.y_var, linestyle = 'solid', marker = 'o', markersize=2, linewidth = '1.4', c='b')
        
        ax.xaxis.set_tick_params(rotation=70, labelsize=10)
        
        #ax.set_xticks(np.arange(min(bike_sales_data.index),max(bike_sales_data.index),12))
        
        ax.set_yticks(np.arange(0, y_upper_bound, 10))
        
        ax.yaxis.set_tick_params(labelsize=10)
        
        ax.spines['top'].set_visible(False)
        
        ax.spines['right'].set_visible(False)
        
        ax.xaxis.labelpad=20
        
        ax.yaxis.labelpad=20
        
        ax.grid (color='grey', linestyle='-', linewidth=0.25, alpha=1)
        
        ax.set_xlabel(self.x_var_name, fontsize = 12)
        ax.set_ylabel(self.y_var_name, fontsize = 12)
        
        
        #ax.set_xlim('2021-01', '2022-01')

# %%
#Could make a matrix with all the variables and variable names in. Then loop through. 


sales_plot = var_graph(bike_sales_data.index, bike_sales_data['sales']/1000, 'Year', 'Marketing Channel Spend (in £1000)', 400)

# %%
#sales_plot.var_graph

print(var_graph.__slots__)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 3
#       1 #sales_plot.var_graph
# ----> 3 print(var_graph.__slots__)
#
# AttributeError: type object 'var_graph' has no attribute '__slots__'

# %%
sales_plot.plot_graph()

#https://stackoverflow.com/questions/43620690/matplotlib-creating-a-class-that-can-be-plotted
#The blog above shows how to sort this.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sales_plot.plot_graph()
#
# Cell In[11], line 19, in var_graph.plot_graph(self)
#      15 ax.xaxis.set_tick_params(rotation=70, labelsize=10)
#      17 #ax.set_xticks(np.arange(min(bike_sales_data.index),max(bike_sales_data.index),12))
# ---> 19 ax.set_yticks(np.arange(0, y_upper_bound, 10))
#      21 ax.yaxis.set_tick_params(labelsize=10)
#      23 ax.spines['top'].set_visible(False)
#
# NameError: name 'y_upper_bound' is not defined

# %%
base_rate_usa = pd.read_csv("base_rate_usa.csv")

gdp_usa = pd.read_csv("gdp_usa.csv")

unemployment_rate_usa = pd.read_csv("unemployment_rate_usa.csv")

# %% [markdown]
# #Cleansing Base Rate Data

# %%
#Delete this when finished cleansing

base_rate_usa = pd.read_csv("base_rate_usa.csv")

# %%
base_rate_usa['observation_date'] = pd.to_datetime (base_rate_usa['observation_date'])

base_rate_usa['observation_date'] = base_rate_usa['observation_date'].dt.strftime('%Y-%m')

base_rate_usa = base_rate_usa.set_index('observation_date')

#base_rate_usa['FEDFUNDS'] = base_rate_usa['base_rate']


base_rate_usa = base_rate_usa.rename(columns={'FEDFUNDS': 'base_rate'})

# %%
base_rate_usa

# %%
base_rate_usa['base_rate']

# %%
sales_plot = var_graph(base_rate_usa.index, base_rate_usa['base_rate'], 'Month', 'Base Rate', 20)

sales_plot.plot_graph()

#https://stackoverflow.com/questions/43620690/matplotlib-creating-a-class-that-can-be-plotted
#The blog above shows how to sort this.

# %% [markdown]
# ### Testing PYMC

# %%
import pandas as pd
import numpy as np
import sktime as skt
import pymc_marketing as pymc
import sktime as skt
#from pymc_marketing.mmm.delayed_saturation_mmm import DelayedSaturatedMMM

import arviz as az
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pymc_marketing.mmm import MMM, GeometricAdstock, LogisticSaturation
from pymc_marketing.mmm.transformers import geometric_adstock, logistic_saturation

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
y = bike_sales_data['sales']
x = bike_sales_data.drop('sales', axis=1)

# %%
dummy_model = pymc(
    date_column="",
    channel_columns=[""],
    adstock=GeometricAdstock(l_max=4),
    saturation=LogisticSaturation(),
)
dummy_model.default_model_config
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 dummy_model = pymc(
#       2     date_column="",
#       3     channel_columns=[""],
#       4     adstock=GeometricAdstock(l_max=4),
#       5     saturation=LogisticSaturation(),
#       6 )
#       7 dummy_model.default_model_config
#
# TypeError: 'module' object is not callable

# %%
n_order = 8

coords = {"date": bike_sales_data.index, "fourier_mode": np.arange(2 * n_order)}

with pm.Model(coords=coords) as base_model:
    --- coords ---
    base_model.add_coord(name="date", values=date, mutable=True)
    base_model.add_coord(name="fourier_mode", values=np.arange(2 * n_order), mutable=False)

    --- data containers ---
    z_scaled_ = pm.MutableData(name="z_scaled", value=z_scaled, dims="date")

    --- priors ---
    #intercept
    a = pm.Normal(name="a", mu=0, sigma=4)
    #trend
    b_trend = pm.Normal(name="b_trend", mu=0, sigma=2)
    #seasonality
    b_fourier = pm.Laplace(name="b_fourier", mu=0, b=2, dims="fourier_mode")
    #regressor
    b_z = pm.HalfNormal(name="b_z", sigma=2)
    #standard deviation of the normal likelihood
    sigma = pm.HalfNormal(name="sigma", sigma=0.5)
    degrees of freedom of the t distribution
    nu = pm.Gamma(name="nu", alpha=25, beta=2)

    --- model parametrization ---
    trend = pm.Deterministic(name="trend", var=a + b_trend * t, dims="date")
    seasonality = pm.Deterministic(
        name="seasonality", var=pm.math.dot(fourier_features, b_fourier), dims="date"
    )
    z_effect = pm.Deterministic(name="z_effect", var=b_z * z_scaled_, dims="date")
    mu = pm.Deterministic(name="mu", var=trend + seasonality + z_effect, dims="date")

    --- likelihood ---
    pm.StudentT(name="likelihood", nu=nu, mu=mu, sigma=sigma, observed=y_scaled, dims="date")

    --- prior samples ---
    base_model_prior_predictive = pm.sample_prior_predictive()

pm.model_to_graphviz(model=base_model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 7
#       3 coords = {"date": bike_sales_data.index, "fourier_mode": np.arange(2 * n_order)}
#       5 with pm.Model(coords=coords) as base_model:
#       6     # --- coords ---
# ----> 7     base_model.add_coord(name="date", values=date, mutable=True)
#       8     base_model.add_coord(name="fourier_mode", values=np.arange(2 * n_order), mutable=False)
#      10     # --- data containers ---
#
# NameError: name 'date' is not defined

# %%
dummy_model = pymc(
    date_column = 'date',
    channel_columns = ['branded_search_spend', 'nonbranded_search_spend', 'facebook_spend', 'print_spend'],
    control_columns = ['tv_spend', 'radio_spend'],
    adstock_max_lag = 8,
)


#Taken from 44mins in the video:

#https://www.youtube.com/watch?v=lJ_qq_IVUgg&t=1779s

#Check out this vid as well: https://www.youtube.com/watch?v=4FznIhcrHCA&t=1030s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dummy_model = pymc(
#       2     date_column = 'date',
#       3     channel_columns = ['branded_search_spend', 'nonbranded_search_spend', 'facebook_spend', 'print_spend'],
#       4     control_columns = ['tv_spend', 'radio_spend'],
#       5     adstock_max_lag = 8,
#       6 )
#       9 #Taken from 44mins in the video:
#      10
#      11 #https://www.youtube.com/watch?v=lJ_qq_IVUgg&t=1779s
#      12
#      13 #Check out this vid as well: https://www.youtube.com/watch?v=4FznIhcrHCA&t=1030s
#
# TypeError: 'module' object is not callable

# %% [markdown]
# ##Testing Robyn

# %%
import importlib
import robyn
import os
import pandas as pd
pkg = importlib.import_module("robyn")

# %%
#Step 3: Define the Path to Tutorials
tutorials_path = pkg.__path__[0] + "/tutorials"

# %%
import sys
import os

notebook_path = os.path.abspath("")
robyn_path = os.path.abspath(os.path.join(notebook_path, "../../"))
if robyn_path not in sys.path:
    sys.path.append(robyn_path)

# %%
from robyn.data.entities.mmmdata import MMMData
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from robyn.data.entities.mmmdata import MMMData
#
# ModuleNotFoundError: No module named 'robyn.data'

# %%
import pandas as pd

from robyn.robyn import Robyn
from robyn.data.entities.mmmdata import MMMData
from robyn.data.entities.holidays_data import HolidaysData
from robyn.data.entities.hyperparameters import Hyperparameters, ChannelHyperparameters
from robyn.data.entities.enums import AdstockType, DependentVarType
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[29], line 3
#       1 import pandas as pd
# ----> 3 from robyn.robyn import Robyn
#       4 from robyn.data.entities.mmmdata import MMMData
#       5 from robyn.data.entities.holidays_data import HolidaysData
#
# ImportError: cannot import name 'Robyn' from 'robyn.robyn' (/opt/anaconda3/envs/marketing_env/lib/python3.13/site-packages/robyn/robyn.cpython-313-darwin.so)

# %%
bike_sales_data
# Out:
#                   sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23   58850.0000               1528.80                 463.3200
# 2017-07-30   62050.0000               1575.60                 468.0000
# 2017-08-06   59388.0000               1544.40                 477.3600
# 2017-08-13   56964.0000               1528.80                 468.0000
# 2017-08-20   53460.0000               1560.00                 458.6400
# ...                 ...                   ...                      ...
# 2022-06-12   98173.4880               3466.32                 814.9285
# 2022-06-19  104221.7248               3534.96                 829.0855
# 2022-06-26  103283.6800               3363.36                 793.6930
# 2022-07-03  105279.5200               3534.96                 829.0855
# 2022-07-10   98221.7248               3363.36                 793.6930
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# ...

# %%
mmm_data = MMMData(data=bike_sales_data, mmmdata_spec=mmm_data_spec)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mmm_data = MMMData(data=bike_sales_data, mmmdata_spec=mmm_data_spec)
#
# NameError: name 'MMMData' is not defined

# %%
mmm_data_spec = MMMData.MMMDataSpec(
    dep_var="sales",  # Target variable
    dep_var_type="revenue",  # Type: "revenue" or "conversion"
    date_var="Week",  # Date column name
    paid_media_spends=[
        "branded_search_spend",
        "nonbranded_search_spend",
        "facebook_spend",
        "print_spend",
        "ooh_spend",
    ],  # Media spend columns
  # Non-paid marketing activities
    window_start="2017-07-23",  # Analysis start date
    window_end="2022-07-10",  # Analysis end date
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 mmm_data_spec = MMMData.MMMDataSpec(
#       2     dep_var="sales",  # Target variable
#       3     dep_var_type="revenue",  # Type: "revenue" or "conversion"
#       4     date_var="Week",  # Date column name
#       5     paid_media_spends=[
#       6         "branded_search_spend",
#       7         "nonbranded_search_spend",
#       8         "facebook_spend",
#       9         "print_spend",
#      10         "ooh_spend",
#      11     ],  # Media spend columns
#      12   # Non-paid marketing activities
#      13     window_start="2017-07-23",  # Analysis start date
#      14     window_end="2022-07-10",  # Analysis end date
#      15 )
#      17 mmm_data = MMMData(data=bike_sales_data, mmmdata_spec=mmm_data_spec)
#
# NameError: name 'MMMData' is not defined

# %%
bike_sales_data.index.max()
# Out:
# Timestamp('2022-07-10 00:00:00')

# %% [markdown]
# ### Testing PYMC Again!

# %%
import warnings

import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import beta, gamma, halfnorm, laplace, norm, truncnorm
from pymc_marketing.mmm import MMM, GeometricAdstock, LogisticSaturation
from pymc_marketing.mmm.transformers import geometric_adstock, logistic_saturation
from sklearn.preprocessing import MaxAbsScaler
from sklearn.linear_model import LinearRegression
import data_generator as dg

#warnings.filterwarnings("ignore", category=FutureWarning)

az.style.use("arviz-darkgrid")
plt.rcParams["figure.figsize"] = [12, 7]
plt.rcParams["figure.dpi"] = 100

# %%
np.random.seed(10)

# Set parameters for data generator
start_date = "2021-01-01"
periods = 52 * 3
channels = ["tv", "social", "search"]
adstock_alphas = [0.50, 0.25, 0.05]
saturation_lamdas = [1.5, 2.5, 3.5]
betas = [350, 150, 50]
spend_scalars = [10, 15, 20]

df = dg.data_generator(start_date, periods, channels, spend_scalars, adstock_alphas, saturation_lamdas, betas)

# Scale betas using maximum sales value - this is so it is comparable to the fitted beta from pymc (pymc does feature and target scaling using MaxAbsScaler from sklearn)
betas_scaled = [
    ((df["tv_sales"] / df["sales"].max()) / df["tv_saturated"]).mean(),
    ((df["social_sales"] / df["sales"].max()) / df["social_saturated"]).mean(),
    ((df["search_sales"] / df["sales"].max()) / df["search_saturated"]).mean()
]

# Calculate contributions
contributions = np.asarray([
    round((df["tv_sales"].sum() / df["sales"].sum()), 2),
    round((df["social_sales"].sum() / df["sales"].sum()), 2),
    round((df["search_sales"].sum() / df["sales"].sum()), 2),
    round((df["demand"].sum() / df["sales"].sum()), 2)
])

df[["date", "demand", "demand_proxy", "tv_spend_raw", "social_spend_raw", "search_spend_raw", "sales"]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 12
#       9 betas = [350, 150, 50]
#      10 spend_scalars = [10, 15, 20]
# ---> 12 df = dg.data_generator(start_date, periods, channels, spend_scalars, adstock_alphas, saturation_lamdas, betas)
#      14 # Scale betas using maximum sales value - this is so it is comparable to the fitted beta from pymc (pymc does feature and target scaling using MaxAbsScaler from sklearn)
#      15 betas_scaled = [
#      16     ((df["tv_sales"] / df["sales"].max()) / df["tv_saturated"]).mean(),
#      17     ((df["social_sales"] / df["sales"].max()) / df["social_saturated"]).mean(),
#      18     ((df["search_sales"] / df["sales"].max()) / df["search_saturated"]).mean()
#      19 ]
#
# AttributeError: module 'data_generator' has no attribute 'data_generator'

# %%
dummy_model = MMM(
    date_column="",
    channel_columns=[""],
    adstock=GeometricAdstock(l_max=4),
    saturation=LogisticSaturation(),
)
dummy_model.default_model_config
# Out:
# {'intercept': Prior("Normal", mu=0, sigma=2),
#  'likelihood': Prior("Normal", sigma=Prior("HalfNormal", sigma=2)),
#  'gamma_control': Prior("Normal", mu=0, sigma=2, dims="control"),
#  'gamma_fourier': Prior("Laplace", mu=0, b=1, dims="fourier_mode"),
#  'adstock_alpha': Prior("Beta", alpha=1, beta=3, dims="channel"),
#  'saturation_lam': Prior("Gamma", alpha=3, beta=1, dims="channel"),
#  'saturation_beta': Prior("HalfNormal", sigma=2, dims="channel")}

# %%
bike_sales_data
# Out:
#                   sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23   58850.0000               1528.80                 463.3200
# 2017-07-30   62050.0000               1575.60                 468.0000
# 2017-08-06   59388.0000               1544.40                 477.3600
# 2017-08-13   56964.0000               1528.80                 468.0000
# 2017-08-20   53460.0000               1560.00                 458.6400
# ...                 ...                   ...                      ...
# 2022-06-12   98173.4880               3466.32                 814.9285
# 2022-06-19  104221.7248               3534.96                 829.0855
# 2022-06-26  103283.6800               3363.36                 793.6930
# 2022-07-03  105279.5200               3534.96                 829.0855
# 2022-07-10   98221.7248               3363.36                 793.6930
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# ...

# %%
bike_sales_data['date_col'] = bike_sales_data.index

bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month   date_col
# Week
# 2017-07-23  2017-07 2017-07-23
# 2017-07-30  2017-07 2017-07-30
# ...

# %%
# set date column
date_col = "date_col"

# set outcome column
y_col = "sales"

# set marketing variables
channel_cols = ["branded_search_spend",
                "nonbranded_search_spend",
                "facebook_spend"]

# set control variables  ---- Needs changing to real controls! 
control_cols = ["print_spend"]

# create arrays
X = bike_sales_data[[date_col] + channel_cols + control_cols]
y = bike_sales_data[y_col]

# set test (out-of-sample) length
test_len = 8

# create train and test indexs
train_idx = slice(0, len(bike_sales_data) - test_len)
out_of_time_idx = slice(len(bike_sales_data) - test_len, len(bike_sales_data))

# %%
mmm_default = MMM(
    adstock=GeometricAdstock(l_max=8),
    saturation=LogisticSaturation(),
    date_column=date_col,
    channel_columns=channel_cols,
    control_columns=control_cols,
)

mmm_default.default_model_config
# Out:
# {'intercept': Prior("Normal", mu=0, sigma=2),
#  'likelihood': Prior("Normal", sigma=Prior("HalfNormal", sigma=2)),
#  'gamma_control': Prior("Normal", mu=0, sigma=2, dims="control"),
#  'gamma_fourier': Prior("Laplace", mu=0, b=1, dims="fourier_mode"),
#  'adstock_alpha': Prior("Beta", alpha=1, beta=3, dims="channel"),
#  'saturation_lam': Prior("Gamma", alpha=3, beta=1, dims="channel"),
#  'saturation_beta': Prior("HalfNormal", sigma=2, dims="channel")}

# %%
fit_kwargs = {
    "tune": 1_000,
    "chains": 4,
    "draws": 1_000,
    "target_accept": 0.9,
}

mmm_default.fit(X[train_idx], y[train_idx], **fit_kwargs)
# Out:
# ERROR (pytensor.graph.rewriting.basic): Rewrite failure due to: constant_folding
# ERROR (pytensor.graph.rewriting.basic): node: ExpandDims{axis=0}(3)
# ERROR (pytensor.graph.rewriting.basic): TRACEBACK:
# ERROR (pytensor.graph.rewriting.basic): Traceback (most recent call last):
#   File "/opt/anaconda3/envs/marketing_env/lib/python3.13/site-packages/pytensor/graph/rewriting/basic.py", line 1922, in process_node
#     replacements = node_rewriter.transform(fgraph, node)
#   File "/opt/anaconda3/envs/marketing_env/lib/python3.13/site-packages/pytensor/graph/rewriting/basic.py", line 1086, in transform
#     return self.fn(fgraph, node)
#            ~~~~~~~^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/marketing_env/lib/python3.13/site-packages/pytensor/tensor/rewriting/basic.py", line 1160, in constant_folding
#     return unconditional_constant_folding.transform(fgraph, node)
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^
# ...

# %%
mmm_default.save("mmm_default.nc")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 mmm_default.save("mmm_default.nc")
#
# File /opt/anaconda3/envs/marketing_env/lib/python3.13/site-packages/pymc_marketing/model_builder.py:478, in ModelBuilder.save(self, fname)
#     476     self.idata.to_netcdf(str(file))
#     477 else:
# --> 478     raise RuntimeError("The model hasn't been fit yet, call .fit() first")
#
# RuntimeError: The model hasn't been fit yet, call .fit() first

# %% [markdown]
# ### SKLearn Testing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score, TimeSeriesSplit
from sklearn.base import BaseEstimator, TransformerMixin, RegressorMixin
from sklearn.utils.validation import check_is_fitted, check_array
# %matplotlib inline
import seaborn as sns

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
X = bike_sales_data.drop(columns=['sales'])
y = bike_sales_data['sales']

# %%
#with check for a greater than 0
class ExponentialSaturation(BaseEstimator,TransformerMixin):
    def __init__(self,a=.0010):
        if a > 0:
            self.a = a
        else:
            self.a = 1
    def fit(self,X,y=None):
        X = check_array(X)
        self._check_n_features(X,reset=True)
        return self
    def transform(self,X):
        check_is_fitted(self)
        X = check_array(X)
        self._check_n_features(X,reset=False)

        return 1 - np.exp(-self.a*X)

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
spend_test = bike_sales_data["branded_search_spend"]
spend_test = spend_test.to_frame("branded_search_spend")

# %%
spend_test.head()
# Out:
#             branded_search_spend
# Week
# 2017-07-23                1528.8
# 2017-07-30                1575.6
# 2017-08-06                1544.4
# 2017-08-13                1528.8
# 2017-08-20                1560.0

# %%
SE = ExponentialSaturation()
spend_test["Saturated_spends"] = SE.fit_transform(spend_test[["branded_search_spend"]])
spend_test
# Out:
#             branded_search_spend  Saturated_spends
# Week
# 2017-07-23               1528.80          0.783204
# 2017-07-30               1575.60          0.793117
# 2017-08-06               1544.40          0.786560
# 2017-08-13               1528.80          0.783204
# 2017-08-20               1560.00          0.789864
# ...                          ...               ...
# 2022-06-12               3466.32          0.968768
# 2022-06-19               3534.96          0.970840
# 2022-06-26               3363.36          0.965381
# 2022-07-03               3534.96          0.970840
# 2022-07-10               3363.36          0.965381
#
# [260 rows x 2 columns]

# %%
from scipy.signal import convolve2d
import numpy as np
class ExponentialCarryover(BaseEstimator, TransformerMixin):
    def __init__(self, strength=0.5, length=1):
        self.strength = strength
        self.length = length
    def fit(self, X, y=None):
        X = check_array(X)
        self._check_n_features(X, reset=True)
        self.sliding_window_ = (
            self.strength ** np.arange(self.length + 1)
        ).reshape(-1, 1)
        return self
    def transform(self, X: np.ndarray):
        check_is_fitted(self)
        X = check_array(X)
        self._check_n_features(X, reset=False)
        convolution = convolve2d(X, self.sliding_window_)
        if self.length > 0:
            convolution = convolution[: -self.length]
        return convolution

# %%
spend_test
# Out:
#             branded_search_spend  Saturated_spends
# Week
# 2017-07-23               1528.80          0.783204
# 2017-07-30               1575.60          0.793117
# 2017-08-06               1544.40          0.786560
# 2017-08-13               1528.80          0.783204
# 2017-08-20               1560.00          0.789864
# ...                          ...               ...
# 2022-06-12               3466.32          0.968768
# 2022-06-19               3534.96          0.970840
# 2022-06-26               3363.36          0.965381
# 2022-07-03               3534.96          0.970840
# 2022-07-10               3363.36          0.965381
#
# [260 rows x 2 columns]

# %%
CE = ExponentialCarryover()
spend_test["Carried_spends"] = CE.fit_transform(spend_test[["branded_search_spend"]])
spend_test
# Out:
#             branded_search_spend  Saturated_spends  Carried_spends
# Week
# 2017-07-23               1528.80          0.783204         1528.80
# 2017-07-30               1575.60          0.793117         2340.00
# 2017-08-06               1544.40          0.786560         2332.20
# 2017-08-13               1528.80          0.783204         2301.00
# 2017-08-20               1560.00          0.789864         2324.40
# ...                          ...               ...             ...
# 2022-06-12               3466.32          0.968768         5165.16
# 2022-06-19               3534.96          0.970840         5268.12
# 2022-06-26               3363.36          0.965381         5130.84
# 2022-07-03               3534.96          0.970840         5216.64
# 2022-07-10               3363.36          0.965381         5130.84
#
# [260 rows x 3 columns]

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
adstock = ColumnTransformer(
    [
     ('branded_search_spend', Pipeline([
                           ('carryover', ExponentialCarryover()),
                           ('saturation', ExponentialSaturation())
     ]), ['branded_search_spend']),
    ],
    remainder='passthrough'
)

# %%
model = Pipeline([
                  ('adstock', adstock),
                  ('regression', LinearRegression())
])

# %%
y = y.to_frame('sales')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/5k/0mrs71sj38b3m6trnqsfqlx00000gp/T/ipykernel_46879/1419620011.py in ?()
# ----> 1 y = y.to_frame('sales')
#
# /opt/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
X = X.drop('Month', axis = 1)

# %%
X
# Out:
#             branded_search_spend  nonbranded_search_spend  facebook_spend  \
# Week
# 2017-07-23               1528.80                 463.3200        802.6200
# 2017-07-30               1575.60                 468.0000        819.3120
# 2017-08-06               1544.40                 477.3600        749.0340
# 2017-08-13               1528.80                 468.0000        741.4680
# 2017-08-20               1560.00                 458.6400        811.2000
# ...                          ...                      ...             ...
# 2022-06-12               3466.32                 814.9285       1715.8284
# 2022-06-19               3534.96                 829.0855       1802.8296
# 2022-06-26               3363.36                 793.6930       1631.2296
# 2022-07-03               3534.96                 829.0855       1855.8540
# 2022-07-10               3363.36                 793.6930       1715.3136
#
#             print_spend  ooh_spend  tv_spend  radio_spend
# Week
# ...

# %%
model.fit(X,y)
# Out:
# Pipeline(steps=[('adstock',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('branded_search_spend',
#                                                   Pipeline(steps=[('carryover',
#                                                                    ExponentialCarryover()),
#                                                                   ('saturation',
#                                                                    ExponentialSaturation())]),
#                                                   ['branded_search_spend'])])),
#                 ('regression', LinearRegression())])

# %%
print(cross_val_score(model, X, y, cv=TimeSeriesSplit()).mean())
# Out:
# -0.02694117475597746

# %%
pred_v_actual_df = pd.DataFrame(data=model.predict(X),columns=["Predicted Sales"],index=X.index)
pred_v_actual_df["Actual Sales"]=y
pred_v_actual_df
# Out:
#             Predicted Sales  Actual Sales
# Week
# 2017-07-23     45696.240814    58850.0000
# 2017-07-30     65734.167747    62050.0000
# 2017-08-06     65904.436864    59388.0000
# 2017-08-13     64953.028545    56964.0000
# 2017-08-20     65038.325035    53460.0000
# ...                     ...           ...
# 2022-06-12    102704.698418    98173.4880
# 2022-06-19    109984.272551   104221.7248
# 2022-06-26    107894.466493   103283.6800
# 2022-07-03    110042.955498   105279.5200
# 2022-07-10    108058.441532    98221.7248
#
# [260 rows x 2 columns]

# %%
from sklearn.model_selection import KFold, cross_val_score

# %%
cv = KFold(n_splits=5,shuffle=True,random_state=45)
#r2 = make_scorer(r2_score)
r2_val_score = cross_val_score(clf, x, y, scoring='r2')
scores=[r2_val_score.mean()]
return scores

#Blog below on how to set scoring metric to R2:
#https://medium.com/@chanakapinfo/evaluating-model-performance-with-k-fold-cross-validation-a-practical-example-485aaeb01dc0
#Might need to look for Adjusted R2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[109], line 3
#       1 cv = KFold(n_splits=5,shuffle=True,random_state=45)
#       2 #r2 = make_scorer(r2_score)
# ----> 3 r2_val_score = cross_val_score(clf, x, y, scoring='r2')
#       4 scores=[r2_val_score.mean()]
#       5 return scores
#
# NameError: name 'clf' is not defined

# %%
from sklearn import metrics
scores = cross_val_score(
    reg, X, y, cv=5, scoring='f1_macro')
scores
array([0.96, 1., 0.96, 0.96, 1.])

# %%
sns.lineplot(data=pred_v_actual_df);

# %% [markdown]
# ### Testing Setting AdStock Manually

# %%
bike_sales_data.head()
# Out:
#               sales  branded_search_spend  nonbranded_search_spend  \
# Week
# 2017-07-23  58850.0                1528.8                   463.32
# 2017-07-30  62050.0                1575.6                   468.00
# 2017-08-06  59388.0                1544.4                   477.36
# 2017-08-13  56964.0                1528.8                   468.00
# 2017-08-20  53460.0                1560.0                   458.64
#
#             facebook_spend  print_spend  ooh_spend  tv_spend  radio_spend  \
# Week
# 2017-07-23         802.620            0          0         0            0
# 2017-07-30         819.312            0          0         0            0
# 2017-08-06         749.034            0          0         0            0
# 2017-08-13         741.468            0          0         0            0
# 2017-08-20         811.200            0          0         0            0
#
#               Month
# Week
# 2017-07-23  2017-07
# 2017-07-30  2017-07
# 2017-08-06  2017-08
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Geometric Adstock function
def geometric_adstock(series, decay_factor):
    adstock_series = np.zeros_like(series, dtype=float)

    # Calculate the adstock for each period
    for t in range(len(series)):
        adstock_series[t] = series[t] + (decay_factor * adstock_series[t-1] if t > 0 else 0)
    
    return adstock_series

# Example media exposure data
media_exposure = np.array([100, 100, 300, 400, 500, 300])

# Different decay factors (theta)
decay_factors = [0.3, 0.5, 0.7, 0.9]

# DataFrame to store results for each decay factor
results_df = pd.DataFrame({'Media_Exposure': media_exposure})

# Calculate adstock values for each decay factor
for theta in decay_factors:
    adstock_values = geometric_adstock(media_exposure, theta)
    results_df[f'Adstock (Theta={theta})'] = adstock_values

# Show the DataFrame
print(results_df)

# Plot the adstock values for different decay factors
plt.figure(figsize=(10, 6))
for theta in decay_factors:
    plt.plot(results_df['Media_Exposure'], results_df[f'Adstock (Theta={theta})'], label=f'Theta={theta}')
plt.xlabel('Period')
plt.ylabel('Adstocked Impressions')
plt.title('Geometric Adstock with Different Theta Values')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Geometric Adstock function
def geometric_adstock(series, decay_factor):
    adstock_series = np.zeros_like(series, dtype=float)

    # Calculate the adstock for each period
    for t in range(len(series)):
        adstock_series[t] = series[t] + (decay_factor * adstock_series[t-1] if t > 0 else 0)
    
    return adstock_series

# %%
zeros_like

# %%
#Writing the adstock function here: https://medium.com/@mail2rajivgopinath/key-statistics-terms-22-geometric-adstock-a3b30c5b8f58

# %%
import nevergrad as ng

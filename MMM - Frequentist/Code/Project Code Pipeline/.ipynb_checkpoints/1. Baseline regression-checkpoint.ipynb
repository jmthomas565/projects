# %%
import os 
cwd = os.getcwd()
cwd

os.chdir("/Users/jmthomas565/Desktop/Education/Applied Stats MSc/MSc Project/Git Files/msc-project-source-code-files-24-25-jmthomas565/Code/Project Code Pipeline")

new_cwd = os.getcwd() 

new_cwd
# Out:
# '/Users/jmthomas565/Desktop/Education/Applied Stats MSc/MSc Project/Git Files/msc-project-source-code-files-24-25-jmthomas565/Code/Project Code Pipeline'

# %%
# %run 00_inititial_transformations.ipynb
# Out:
# ['2017-07-01', '2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05'] ... ['2022-09-27', '2022-09-28', '2022-09-29', '2022-09-30', '2022-10-01']

# %%
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge

# %% [markdown]
# ### Baseline Ridge Regression (without any transformations)

# %%
#Cross-validation hold-out splits
hold_out_split = -26
y_train_calib = y_train.iloc[:hold_out_split]
y_train_hold_out = y_train.iloc[hold_out_split:]

#Defining adj_R^2 function
def adj_r2(y_true, y_pred, p):
    r2 = r2_score(y_true, y_pred)
    n = len(y_true)
    #Making sure the denominator of adj R^2 > 0
    if n - p - 1 <= 0:
        return np.nan
    calculation = 1 - (1 - r2) * (n - 1) / (n - p - 1)
    return calculation

#insantiating the model
def test_model_adjusted_r2(X_train, regressors):
    ridge = Ridge(alpha=1.0)
    

    #splitting for hold-out cv
    X_train_calib = X_train.iloc[:hold_out_split]
    X_val_hold_out = X_train.iloc[hold_out_split:]

    ridge.fit(X_train_calib, y_train_calib)
    y_pred = ridge.predict(X_val_hold_out)

    score = adj_r2(y_train_hold_out, y_pred, p=X_train_calib.shape[1])
    print(f"{regressors}: Adjusted R2 = {round(score, 4)}")

#testing different numbers of regressors
X_1reg = X_train.iloc[:, :1]
test_model_adjusted_r2(X_1reg, "1 regressor")

X_2reg = X_train.iloc[:, :2]
test_model_adjusted_r2(X_2reg, "2 regressor")

X_3reg = X_train.iloc[:, :3]  
test_model_adjusted_r2(X_3reg, "3 regressor")

X_4reg = X_train.iloc[:, :4]
test_model_adjusted_r2(X_4reg, "4 regressor")

X_5reg = X_train.iloc[:, :5]
test_model_adjusted_r2(X_5reg, "5 regressor")

X_6reg = X_train.iloc[:, :6]
test_model_adjusted_r2(X_6reg, "6 regressor")

X_7reg = X_train.iloc[:, :7]
test_model_adjusted_r2(X_7reg, "7 regressor")
# Out:
# 1 regressor: Adjusted R2 = -0.2957
# 2 regressor: Adjusted R2 = 0.056
# 3 regressor: Adjusted R2 = -0.0099
# 4 regressor: Adjusted R2 = 0.2642
# 5 regressor: Adjusted R2 = 0.2132
# 6 regressor: Adjusted R2 = 0.1017
# 7 regressor: Adjusted R2 = -0.4588
